# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
data = pd.read_csv(r"Covid-19.csv")

# %%
data
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                                Maharashtra      5963420  135708     5710356
# 1                                  Karnataka      2801936  130894     2637279
# 2                                     Kerala      2797747  107300     2678499
# 3                                 Tamil Nadu      2414680   78780     2304885
# 4                             Andhra Pradesh      1844917   65244     1767404
# 5                              Uttar Pradesh      1704139    4957     1677050
# 6                                West Bengal      1479523   23013     1439215
# 7                                      Delhi      1432168    2372     1404889
# 8                               Chhattisgarh       990323    9531      967415
# 9                                  Rajasthan       950961    3451      938619
# 10                                    Odisha       873925   35243      835132
# ...

# %%
data.columns
# Out:
# Index(['State/UTs', 'Total Cases', 'Active', 'Discharged', 'Deaths',
#        'Active Ratio', 'Discharge Ratio', 'Death Ratio'],
#       dtype='object')

# %%
data.head()
# Out:
#         State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0     Maharashtra      5963420  135708     5710356  117356          2.28
# 1       Karnataka      2801936  130894     2637279   33763          4.67
# 2          Kerala      2797747  107300     2678499   11948          3.84
# 3      Tamil Nadu      2414680   78780     2304885   31015          3.26
# 4  Andhra Pradesh      1844917   65244     1767404   12269          3.54
#
#    Discharge Ratio  Death Ratio
# 0            95.76         1.97
# 1            94.12         1.20
# 2            95.74         0.43
# 3            95.45         1.28
# 4            95.80         0.67

# %%
data.tail()
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 31                                    Sikkim        19209    2751       16167
# 32                                   Mizoram        16750    3816       12858
# 33  Dadra and Nagar Haveli and Daman and Diu        10510      74       10432
# 34                               Lakshadweep         9430     345        9039
# 35                       Andaman and Nicobar         7394     105        7162
#
#     Deaths  Active Ratio  Discharge Ratio  Death Ratio
# 31     291         14.32            84.16         1.51
# 32      76         22.78            76.76         0.45
# 33       4          0.70            99.26         0.04
# 34      46          3.66            95.85         0.49
# 35     127          1.42            96.86         1.72

# %%
data.describe()
# Out:
#         Total Cases         Active    Discharged         Deaths  Active Ratio  \
# count  3.600000e+01      36.000000  3.600000e+01      36.000000     36.000000
# mean   8.300492e+05   20259.055556  7.990483e+05   10741.888889      4.012778
# std    1.186261e+06   36523.027439  1.135758e+06   20316.332267      4.959750
# min    7.394000e+03      74.000000  7.162000e+03       4.000000      0.170000
# 25%    5.727625e+04    2561.250000  4.956500e+04     743.500000      0.775000
# 50%    4.125675e+05    3804.500000  3.894255e+05    4208.000000      2.230000
# 75%    9.608015e+05   11795.500000  9.458180e+05   12028.250000      4.190000
# max    5.963420e+06  135708.000000  5.710356e+06  117356.000000     22.780000
#
#        Discharge Ratio  Death Ratio
# count        36.000000    36.000000
# mean         94.743056     1.243056
# std           4.912054     0.563301
# min          76.760000     0.040000
# 25%          94.922500     0.915000
# 50%          96.015000     1.290000
# ...

# %%
data.isnull().sum()
# Out:
# State/UTs          0
# Total Cases        0
# Active             0
# Discharged         0
# Deaths             0
# Active Ratio       0
# Discharge Ratio    0
# Death Ratio        0
# dtype: int64

# %%
sns.relplot(x="Total Cases", y="Discharged", data=data)

# %%
sns.relplot(x="Total Cases", y="Discharged", hue='Active',data=data)

# %%
sns.pairplot(data)

# %%
sns.relplot(x='Active Ratio', y='Discharge Ratio', kind='line', data=data)

# %%
sns.catplot(x='Active Ratio', y='Discharge Ratio', data=data)
